# %% [markdown]
# #### Name :pratheeksha hegde
# # USN  : 4su18cs060

# %% [markdown]
# # List Practice Project1 : Comma Code

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##  Write Code in the cell below:

# %% [markdown]
# # List Practice Project2 : Character Picture Grid

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Write Code in the cells below
